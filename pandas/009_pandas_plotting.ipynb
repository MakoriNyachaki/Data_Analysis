# %% [markdown]
# # Plotting
# We use the standard convention for referencing the matplotlib API

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.close("all")

# %% [markdown]
# The `plt.close` method is used to close a figure window

# %%
ts = pd.Series(np.random.randn(10000), index=pd.date_range("1/1/2024", periods=10000))
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %% [markdown]
# **Note**
#
# When using Jupyter, the plot will appear using `plot()`. Otherwise use `matplotlib.pyplot.show` to show it or `matplotlib.pyplot.savefig` to write it to a file.
#
# `plots()` plots all columns.

# %%
df = pd.DataFrame(
    np.random.randn(10000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)

# %%
df = df.cumsum()
plt.figure()
df.plot()
plt.legend(loc="best")
