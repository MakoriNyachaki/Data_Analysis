# %% [markdown]
# # Categoricals
#
# Helps us to include categorical data in a DataFrame in pandas.

# %%
import numpy as np
import pandas as pd

# %%
cat_df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

# %%
# Converting the raw grades to a categorical data type
cat_df["grade"] = cat_df["raw_grade"].astype("category")

# %%
cat_df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
# Rename the categories to more meaningful names
new_categories = ["very good", "good", "very bad"]
cat_df["grade"] = cat_df["grade"].cat.rename_categories(new_categories)

# %% [markdown]
# Reorder the categories and simultaneously add the missing categories (methods under `Series.cat()` return a new Series by default):

# %%
cat_df["grade"] = cat_df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)

cat_df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
# Sorting is per order in the categories, not lexical order
cat_df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
# Grouping by a categorical column with observed=False also shows empty categories
cat_df.groupby("grade", observed=False).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64
