# %% [markdown]
# # Imports

# %%
import numpy as np

# %% [markdown]
# # Scalars

# %%
s = 5

# %%
s
# Out:
# 5

# %% [markdown]
# # Vectors

# %%
v = np.array([2,6,9])

# %%
v
# Out:
# array([2, 6, 9])

# %% [markdown]
# # Matrices

# %%
m = np.array([[2,4,-5],[3,-6,7]])

# %%
m
# Out:
# array([[ 2,  4, -5],
#        [ 3, -6,  7]])

# %% [markdown]
# # Data Types

# %%
type(s)
# Out:
# int

# %%
type(v)
# Out:
# numpy.ndarray

# %%
type(m)
# Out:
# numpy.ndarray

# %%
s_array = np.array(s)

# %%
s_array
# Out:
# array(5)

# %%
type(s_array)
# Out:
# numpy.ndarray

# %% [markdown]
# # Data Shapes

# %%
m.shape
# Out:
# (2, 3)

# %%
v.shape
# Out:
# (3,)

# %%
# Get an error, s is a scalar with no shape
s.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Get an error, s is a scalar with no shape
# ----> 2 s.shape
#
# AttributeError: 'int' object has no attribute 'shape'

# %%
s_array.shape
# Out:
# ()

# %% [markdown]
# # Making column vectors

# %%
m.reshape(3,2)
# Out:
# array([[ 2,  4],
#        [-5,  3],
#        [-6,  7]])

# %%
v.reshape(3,1)
# Out:
# array([[2],
#        [6],
#        [9]])

# %%
v.reshape(1,3)
# Out:
# array([[2, 6, 9]])
