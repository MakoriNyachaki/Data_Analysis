# %% [markdown]
# # Scalars
#
# ## Imports

# %%
import numpy as np

# %% [markdown]
# ## Addition of scalars

# %%
5 + 20
# Out:
# 25

# %%
5-5
# Out:
# 0

# %% [markdown]
# ## Matrices

# %%
m = np.array([[2,3,4],[6,7,8]])

# %%
n = np.array([[6,8],[4,-9]])

# %%
m + n
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 m + n
#
# ValueError: operands could not be broadcast together with shapes (2,3) (2,2)

# %%
m - n
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 m - n
#
# ValueError: operands could not be broadcast together with shapes (2,3) (2,2)

# %% [markdown]
# ## Vectors

# %%
v1 = np.array([10,20,30])

# %%
v2 = np.array([14,-67])

# %%
v1 + v2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 v1 + v2
#
# ValueError: operands could not be broadcast together with shapes (3,) (2,)

# %%
v1 - v2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 v1 - v2
#
# ValueError: operands could not be broadcast together with shapes (3,) (2,)

# %% [markdown]
# ## Exceptions(Addition with Scalars)

# %% [markdown]
# ### Matrices and Scalars

# %%
m - 9
# Out:
# array([[-7, -6, -5],
#        [-3, -2, -1]])

# %%
m + 2
# Out:
# array([[ 4,  5,  6],
#        [ 8,  9, 10]])

# %%
n + np.array([-12])
# Out:
# array([[ -6,  -4],
#        [ -8, -21]])

# %% [markdown]
# ## Vectors and Scalars

# %%
v1 + 2
# Out:
# array([12, 22, 32])

# %%
v2 - 3
# Out:
# array([ 11, -70])

# %%
v2 + np.array([-10])
# Out:
# array([  4, -77])
